# %%
import sys

print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
# !pip install -q -U transformers

# %%
from transformers import pipeline

# %%
generator = pipeline(
    "text-generation",
    model="gpt2"
)
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  548MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
output = generator(
    "Artificial intelligence is",
    max_new_tokens=30
)

print(output)
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# ...

# %%
output = generator(
    "Artificial intelligence is",
    max_new_tokens=10
)

print(output)
# Out:
# [transformers] Both `max_new_tokens` (=10) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Artificial intelligence is the technology that can make us smarter, more free'}]

# %%
output = generator(
    "Artificial intelligence is",
    max_new_tokens=50
)

print(output)
# Out:
# [transformers] Both `max_new_tokens` (=50) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "Artificial intelligence is a key part of the future of the industry, and it's hard to imagine a better time to have it.\n\nThere are a lot of technological advances ahead that are driving AI to solve the challenges of artificial intelligence. In the next few years"}]

# %%
generator(
    "The future of artificial intelligence is",
    max_new_tokens=30
)
# Out:
# [transformers] Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of artificial intelligence is only going to get better.\n\nHere are some things to keep in mind:\n\n1. The more we know about AI, the better'}]

# %%
generator(
    "A robot entered the classroom and",
    max_new_tokens=30
)
# Out:
# [transformers] Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'A robot entered the classroom and began running with a computer. I told the robot to "Go!" He followed it to the floor and began to run. I told the robot to'}]

# %%
generator(
    "Generative AI can help students by",
    max_new_tokens=30
)
# Out:
# [transformers] Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Generative AI can help students by allowing them to solve a complex problem without having to worry about the "trivial" details of the problem.\n\n"The problem of the'}]

# %%
generator(
    "The capital of India is",
    max_new_tokens=20
)
# Out:
# [transformers] Both `max_new_tokens` (=20) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "The capital of India is the world's largest, and has the sixth-largest GDP. India is also the largest producer of"}]

# %%
generator(
    "Explain artificial intelligence in simple words:",
    max_new_tokens=40
)
# Out:
# [transformers] Both `max_new_tokens` (=40) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Explain artificial intelligence in simple words:\n\n"I am a human being who has never seen or experienced a world without artificial intelligence. I will not deny that I am a human being. I am not a robot, I am a'}]

# %%
output = generator(
    "A robot entered the classroom and",
    max_new_tokens=40,
    temperature=0.2,
    do_sample=True
)

print(output)
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_new_tokens', 'temperature', 'do_sample'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=40) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'A robot entered the classroom and began to teach the class.\n\n"The teacher said, \'You\'re going to be a robot,\'" said the teacher, who asked not to be identified. "I said, \'What are'}]

# %%
output = generator(
    "A robot entered the classroom and",
    max_new_tokens=40,
    temperature=1.0,
    do_sample=True
)

print(output)
# Out:
# [transformers] Both `max_new_tokens` (=40) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "A robot entered the classroom and entered without warning. It was being taught by a student at the University of Arkansas, not someone from the university's science department. The robot could be seen trying to help the students with a homework question"}]

# %%
output = generator(
    "A robot entered the classroom and",
    max_new_tokens=40,
    temperature=1.5,
    do_sample=True
)

print(output)
# Out:
# [transformers] Both `max_new_tokens` (=40) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'A robot entered the classroom and placed a laser on the ground, in order to "drive us insane" so the child is forced to use a robot instead? Do robots actually mean kids?"\n\nCNET.com reports that'}]

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("gpt2")

# %%
text = "Generative AI is transforming education."

# %%
tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# ['Gener', 'ative', 'ĠAI', 'Ġis', 'Ġtransforming', 'Ġeducation', '.']

# %%
token_ids = tokenizer.encode(text)

print(token_ids)
# Out:
# [8645, 876, 9552, 318, 25449, 3707, 13]

# %%
for token, token_id in zip(tokens, token_ids):
    print(token, "→", token_id)
# Out:
# Gener → 8645
# ative → 876
# ĠAI → 9552
# Ġis → 318
# Ġtransforming → 25449
# Ġeducation → 3707
# . → 13

# %%
text = "Artificial intelligence"
print(tokenizer.tokenize(text))
# Out:
# ['Art', 'ificial', 'Ġintelligence']

# %%
text = "ArtificialIntelligence"
print(tokenizer.tokenize(text))
# Out:
# ['Art', 'ificial', 'Int', 'elligence']

# %%
text = "AI"
print(tokenizer.tokenize(text))
# Out:
# ['AI']
